# %% [markdown]
# # Downloading the data

# %%
import pandas as pd 
import numpy as np
import re 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./Student_Behaviour.csv')
df
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
# 234                                                 No
#
#      Gender Department  Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# 0      Male        BCA       100.0        58.0       79.0       65.0
# 1    Female        BCA        90.0        40.0       70.0       80.0
# ...

# %% [markdown]
# ## Quick look at my data set

# %%
df.sample(10)

#df.head(10)
#df.tail(10)
# Out:
#     Have you completed any certification courses, or are you currently enrolled in any?  \
# 75                                                 Yes
# 44                                                 Yes
# 87                                                 Yes
# 76                                                 Yes
# 102                                                Yes
# 46                                                  No
# 63                                                 Yes
# 40                                                  No
# 85                                                  No
# 116                                                Yes
#
#      Gender                     Department  Height(CM)  Weight(KG)  10th Mark  \
# 75     Male                            BCA       150.0        74.0       75.0
# 44     Male                       Commerce       160.0        65.0       70.0
# 87   Female                            BCA       180.0        75.0       90.2
# ...

# %%
df.shape
print(f"Il y a {df.shape[0]} lignes et {df.shape[1]} colonnes")
#df.sample(10)
# Out:
# Il y a 235 lignes et 19 colonnes

# %% [markdown]
# ## Getting the column names and value type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Have you completed any certification courses, or are you currently enrolled in any?  235 non-null    object
#  1   Gender                                                                               235 non-null    object
#  2   Department                                                                           235 non-null    object
#  3   Height(CM)                                                                           235 non-null    float64
#  4   Weight(KG)                                                                           235 non-null    float64
# ...

# %% [markdown]
# # Cleaning my data set

# %% [markdown]
# ## Renaming my columns

# %%
col_names = {'Have you completed any certification courses, or are you currently enrolled in any?':'Certification (enrolled or completed)','social medai & video games spending Time': 'Time on S-Media & V-Games', 'college mark': 'College score','hobbies':'Hobbies', 'daily studing time':'Daily studying time', 'prefer to study in': 'Preferred study period', 'salary expectation': 'Salary expectation', 'Are you doing a part-time job right now?':'Working part-time', '10th Mark':'10th Grade score', '12th Mark':'12th Grade score', 'possibility of choosing  their career based on their degree :':'Career based on degree'}
df.rename(columns=col_names, inplace= True)

# %% [markdown]
# ## Reordering my columns

# %%
new_col_position = ['Gender',
       'Height(CM)', 'Weight(KG)', 'Hobbies',
       'Time on S-Media & V-Games','10th Grade score', '12th Grade score','Department', 'Certification (enrolled or completed)', 
         'College score',  'Preferred study period','Daily studying time',
    'Do you like your degree?',
       'possibility of choosing  their career based on their degree : ','Salary expectation', 'Travelling Time ','Working part-time',
       'Financial Status', 'Stress Level ']
df = df[new_col_position]
df
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 0      Male       100.0        58.0    Video Games             1.30 - 2 hour
# 1    Female        90.0        40.0         Cinema             1 - 1.30 hour
# 2      Male       159.0        78.0         Cinema          More than 2 hour
# 3    Female       147.0        20.0  Reading books             1.30 - 2 hour
# 4      Male       170.0        54.0    Video Games             1.30 - 2 hour
# ..      ...         ...         ...            ...                       ...
# 230    Male       170.0        76.0    Video Games          More than 2 hour
# 231    Male       172.0        52.0         Cinema            30 - 60 Minute
# 232  Female       139.0        33.0         Cinema            30 - 60 Minute
# 233  Female       153.0        58.0         Cinema          More than 2 hour
# 234  Female       155.0        39.0         Sports            30 - 60 Minute
#
# ...

# %% [markdown]
# ## Putting all the first letters in Capital letters

# %%
df['Financial Status'] = df['Financial Status'].str.capitalize()
df['Stress Level '] = df['Stress Level '].str.capitalize()

df['Stress Level ']
# Out:
# 0           Bad
# 1           Bad
# 2         Awful
# 3           Bad
# 4          Good
#          ...
# 230         Bad
# 231        Good
# 232         Bad
# 233       Awful
# 234    Fabulous
# Name: Stress Level , Length: 235, dtype: object

# %% [markdown]
# ## Searching for missing values/ duplicates

# %%
df.isna().sum()
#df.isna().mean()
# Out:
# Gender                                                            0
# Height(CM)                                                        0
# Weight(KG)                                                        0
# Hobbies                                                           0
# Time on S-Media & V-Games                                         0
# 10th Grade score                                                  0
# 12th Grade score                                                  0
# Department                                                        0
# Certification (enrolled or completed)                             0
# College score                                                     0
# Preferred study period                                            0
# Daily studying time                                               0
# Do you like your degree?                                          0
# possibility of choosing  their career based on their degree :     0
# ...

# %%
(df == '').sum()
#compter les strings vides
# Out:
# Gender                                                            0
# Height(CM)                                                        0
# Weight(KG)                                                        0
# Hobbies                                                           0
# Time on S-Media & V-Games                                         0
# 10th Grade score                                                  0
# 12th Grade score                                                  0
# Department                                                        0
# Certification (enrolled or completed)                             0
# College score                                                     0
# Preferred study period                                            0
# Daily studying time                                               0
# Do you like your degree?                                          0
# possibility of choosing  their career based on their degree :     0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Hobbies'].value_counts()

#etc Value counts nous permet de voir les différentes valeurs existantes dans chaque colonnes 

list_1 = ['Certification (enrolled or completed)', 'Gender', 'Department',
        'Hobbies', 'Daily studying time', 'Preferred study period', 'Do you like your degree?',
       'possibility of choosing  their career based on their degree : ',
       'Time on S-Media & V-Games', 'Travelling Time ', 'Stress Level ',
       'Financial Status', 'Working part-time']

for x in list_1:
    print(df[x].value_counts(),'\n')
    
#je peux aussi utiliser cette boucle qui me permet de vérifier les différentes
#réponses possibles pour toutes ou certaines colonnes
# Out:
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235
#
# 235

# %% [markdown]
# ## Searching for outliers

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)  10th Grade score  12th Grade score  \
# count  235.000000  235.000000        235.000000        235.000000
# mean   157.402128   60.803830         76.842128         68.780128
# std     21.510805   14.895844         13.050800         11.016533
# min      4.500000   20.000000          7.400000         45.000000
# 25%    152.000000   50.000000         70.000000         60.000000
# 50%    160.000000   60.000000         80.000000         69.000000
# 75%    170.000000   70.000000         86.250000         76.000000
# max    192.000000  106.000000         98.000000         94.000000
#
#        College score  Salary expectation
# count     235.000000        2.350000e+02
# mean       70.660553        3.248168e+04
# std        15.727446        1.113146e+05
# min         1.000000        0.000000e+00
# 25%        60.000000        1.500000e+04
# 50%        70.000000        2.000000e+04
# 75%        80.000000        2.500000e+04
# ...

# %% [markdown]
# ## Replacing the outliers

# %%
#nous devons voir quels informations nous allons devoir remplacer qui auront un impact 
# en analysant les boxplots, nous voyons que pour la variable/colonne 'height' nous avons clairement un

# %%
df.loc[df['Height(CM)'] == 4.5]
# Out:
#     Gender  Height(CM)  Weight(KG) Hobbies Time on S-Media & V-Games  \
# 96  Female         4.5        42.0  Cinema             1 - 1.30 hour
#
#     10th Grade score  12th Grade score Department  \
# 96              85.0              90.0        BCA
#
#    Certification (enrolled or completed)  College score  \
# 96                                   Yes           85.0
#
#    Preferred study period Daily studying time Do you like your degree?  \
# 96                Anytime      30 - 60 minute                      Yes
#
#    possibility of choosing  their career based on their degree :   \
# 96                                               100%
#
#     Salary expectation Travelling Time  Working part-time Financial Status  \
# 96               20000  30 - 60 minutes                No            Awful
#
#    Stress Level
# 96          Good

# %%
df.loc[df['Weight(KG)'] == 20]
# Out:
#    Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 3  Female       147.0        20.0  Reading books             1.30 - 2 hour
#
#    10th Grade score  12th Grade score Department  \
# 3              70.0              59.0        BCA
#
#   Certification (enrolled or completed)  College score Preferred study period  \
# 3                                   Yes           58.0                Anytime
#
#   Daily studying time Do you like your degree?  \
# 3          1 - 2 Hour                       No
#
#   possibility of choosing  their career based on their degree :   \
# 3                                                50%
#
#    Salary expectation Travelling Time  Working part-time Financial Status  \
# 3             1500000   0 - 30 minutes                No             Good
#
#   Stress Level
# 3           Bad

# %%
df.loc[df['Weight(KG)'] < 50]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 1    Female        90.0        40.0         Cinema             1 - 1.30 hour
# 3    Female       147.0        20.0  Reading books             1.30 - 2 hour
# 5    Female       139.0        33.0         Cinema            30 - 60 Minute
# 7      Male       152.0        43.0         Sports             1 - 1.30 hour
# 19   Female       109.0        42.0         Cinema             1 - 30 Minute
# 22   Female       142.0        42.0         Cinema             1 - 1.30 hour
# 28   Female       145.0        39.0         Sports                  0 Minute
# 29   Female        99.0        40.0  Reading books             1 - 1.30 hour
# 36   Female       155.0        48.0         Sports             1 - 1.30 hour
# 37   Female       150.0        45.0         Cinema             1 - 1.30 hour
# 40   Female       175.0        43.0         Sports             1 - 30 Minute
# ...

# %%
df.loc[df['10th Grade score'] < 50]

#df.loc[df['10th grade score'] < 30]
# Out:
#      Gender  Height(CM)  Weight(KG)      Hobbies Time on S-Media & V-Games  \
# 4      Male       170.0        54.0  Video Games             1.30 - 2 hour
# 184    Male       150.0        48.0       Sports             1 - 30 Minute
# 196  Female       155.0        39.0       Sports            30 - 60 Minute
# 234  Female       155.0        39.0       Sports            30 - 60 Minute
#
#      10th Grade score  12th Grade score Department  \
# 4                40.0              65.0        BCA
# 184              46.0              48.0  B.com ISM
# 196              45.0              45.0  B.com ISM
# 234              45.0              45.0  B.com ISM
#
#     Certification (enrolled or completed)  College score  \
# 4                                      No           30.0
# 184                                    No           60.0
# 196                                    No           50.0
# 234                                    No           50.0
#
# ...

# %%
df.loc[df['Salary expectation'] > 100000]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 3    Female       147.0        20.0  Reading books             1.30 - 2 hour
# 179  Female       150.0        40.0         Cinema             1 - 1.30 hour
# 185    Male       163.0        80.0         Cinema             1 - 30 Minute
# 188    Male       170.0        80.0         Sports             1 - 30 Minute
#
#      10th Grade score  12th Grade score Department  \
# 3                70.0              59.0        BCA
# 179              80.0              75.0   Commerce
# 185              76.0              47.0  B.com ISM
# 188              67.0              70.0  B.com ISM
#
#     Certification (enrolled or completed)  College score  \
# 3                                     Yes           58.0
# 179                                   Yes           70.0
# 185                                   Yes           30.0
# 188                                   Yes           60.0
#
# ...

# %%
df.loc[df['Salary expectation'] < 10000]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 13     Male       160.0        52.0         Cinema            30 - 60 Minute
# 17     Male       162.0        60.0         Cinema             1 - 1.30 hour
# 51   Female       157.0        53.0         Sports                  0 Minute
# 84     Male       171.0        60.0  Reading books            30 - 60 Minute
# 133    Male       174.0        65.0         Cinema             1 - 30 Minute
# 147  Female       148.0        78.0         Cinema            30 - 60 Minute
# 182  Female       160.0        50.0         Sports            30 - 60 Minute
# 196  Female       155.0        39.0         Sports            30 - 60 Minute
# 210  Female       152.0        32.0         Sports             1 - 1.30 hour
# 211    Male       168.0        75.0         Cinema             1 - 1.30 hour
# 222    Male       160.0        50.0         Sports             1 - 1.30 hour
# ...

# %%
# score 10th grade
# index 80


#pour le outlier du 10th Grade score, la note est trop basse pour que cette personne ait pu passer son année, 
#selon le site, #https://school.careers360.com/boards/cbse/cbse-passing-marks-for-class-10-and-12
#il faut au minimum une note générale de 33 pour passer - et en regardant ses autres scores, nous voyons que ses notes 
#sont >75
#cela reste une supposition, mais il est possible que ce fut soit une erreur d'entrée ou une erreur de la personne
# et j'ai donc décidé de lui attribuer 74, ce qui correspondrait aux autres notes ``

df.iloc[80]
# Out:
# Gender                                                                     Female
# Height(CM)                                                                  155.0
# Weight(KG)                                                                   52.0
# Hobbies                                                                    Sports
# Time on S-Media & V-Games                                           1.30 - 2 hour
# 10th Grade score                                                             74.0
# 12th Grade score                                                             79.0
# Department                                                                    BCA
# Certification (enrolled or completed)                                          No
# College score                                                                75.0
# Preferred study period                                                      Night
# ...

# %%
# poids 20kg
# index 3

# malgré son poids très léger, j'ai décidé de ne pas changer le poids de l'étudiante avec l'index 3 car il se peut
#que ce soit son poids réel/ selon une étude https://sain-et-naturel.ouest-france.fr/tableau-peser-age-taille.html
# une femme d'1m47 a pour poids normal un minimum de 41kg - en comparant une personne plus grande mais qui tombe dans 
# catégorie très mince on voit on peut relativement faire une comparaison et voir que ce n'est pas commun mais
#pas impossible
# Out:
# Gender                                                                    Female
# Height(CM)                                                                 147.0
# Weight(KG)                                                                  20.0
# Hobbies                                                            Reading books
# Time on S-Media & V-Games                                          1.30 - 2 hour
# 10th Grade score                                                            70.0
# 12th Grade score                                                            59.0
# Department                                                                   BCA
# Certification (enrolled or completed)                                        Yes
# College score                                                               58.0
# Preferred study period                                                   Anytime
# Daily studying time                                                   1 - 2 Hour
# ...

# %%
la question sur les salaires et la plus complexe en terme d'outliers
ne connaissant pas la question du sondage, nous ne savons si l'enquête demandait un salaire annuel, mensuel ou par heure
et donc, il est très probable que les réponses où les valeurs sont assez grandes ou assez petites par rapport
à la majorité aient été remplies avec en tête un revenu annuel ou payé par heure et aussi en dollars 
ou est-ce abrégé pour dire 21 000 au lieu de 21

donc en prenant en compte, la majorité, qui est le salaire annuel - j'ai décidé de 
faire une requête où le salaire par mois ne dépassé pas les 100 000 rupees 
j'ai obtenu 4 entrées - sur les 4

les index 3 (voir index 3 ci-dessous) et 179 peuvent être considéré car même si elles font parties de la catégorie haute
des salaires, elles sont plus que plausibles

par contre, pour les index 185 et 188, ça reste très élevé et j'ai décidé de les considérer comme des salaires annuels 
donc je les ai divisés par 12

pour toutes les valeurs en dessous de 10000, j'ai décidé de leur attribuer la moyenne après avoir effectué les

# %%
salaire 1500000
index 3

celui-ci reste un peu plus compliqué, parce que nous ne savons pas si l'erreur est dû à une mauvaise entrée de la 
part de l'étudiante ou de la machine etc
cette erreur est celle qui a le plus gros impact sur notre jeu de donnée
si, par supposition, elle avait compris la question comme étant un salaire annuel, elle serait dans la branche haute
alors, nous pourrions diviser son salaire par 12 et obtenir un salaire mensuel, ou penser qu'un Zéro en trop a été rajouté

# %% [markdown]
# # fixing our dataset

# %% [markdown]
# ## Replacing salary expectation values

# %% [markdown]
# ### Expectation values > 120000

# %%
df.loc[[3,185,188], 'Salary expectation'] = [int(1500000/12) ,int(500000/12),int(700000/12)]
df.loc[[3,185,188]]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 3    Female       147.0        20.0  Reading books             1.30 - 2 hour
# 185    Male       163.0        80.0         Cinema             1 - 30 Minute
# 188    Male       170.0        80.0         Sports             1 - 30 Minute
#
#      10th Grade score  12th Grade score Department  \
# 3                70.0              59.0        BCA
# 185              76.0              47.0  B.com ISM
# 188              67.0              70.0  B.com ISM
#
#     Certification (enrolled or completed)  College score  \
# 3                                     Yes           58.0
# 185                                   Yes           30.0
# 188                                   Yes           60.0
#
#     Preferred study period Daily studying time Do you like your degree?  \
# 3                  Anytime          1 - 2 Hour                       No
# ...

# %% [markdown]
# ### Salary expectation values < 10000

# %%
df.loc[[13, 17, 51, 84, 133, 147, 182, 196, 210, 211, 222, 228, 230, 234], 'Salary expectation'] = np.NaN
df.loc[[13, 17, 51, 84, 133, 147, 182, 196, 210, 211, 222, 228, 230, 234]]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 13     Male       160.0        52.0         Cinema            30 - 60 Minute
# 17     Male       162.0        60.0         Cinema             1 - 1.30 hour
# 51   Female       157.0        53.0         Sports                  0 Minute
# 84     Male       171.0        60.0  Reading books            30 - 60 Minute
# 133    Male       174.0        65.0         Cinema             1 - 30 Minute
# 147  Female       148.0        78.0         Cinema            30 - 60 Minute
# 182  Female       160.0        50.0         Sports            30 - 60 Minute
# 196  Female       155.0        39.0         Sports            30 - 60 Minute
# 210  Female       152.0        32.0         Sports             1 - 1.30 hour
# 211    Male       168.0        75.0         Cinema             1 - 1.30 hour
# 222    Male       160.0        50.0         Sports             1 - 1.30 hour
# ...

# %% [markdown]
# ## ## Changing my nan into 0 and converting my column into intergers

# %%
df['Salary expectation'] = df['Salary expectation'].fillna(0)
df['Salary expectation'] = df['Salary expectation'].astype(int)
df[df['Salary expectation'] == 0]
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 13     Male       160.0        52.0         Cinema            30 - 60 Minute
# 17     Male       162.0        60.0         Cinema             1 - 1.30 hour
# 51   Female       157.0        53.0         Sports                  0 Minute
# 84     Male       171.0        60.0  Reading books            30 - 60 Minute
# 133    Male       174.0        65.0         Cinema             1 - 30 Minute
# 147  Female       148.0        78.0         Cinema            30 - 60 Minute
# 182  Female       160.0        50.0         Sports            30 - 60 Minute
# 196  Female       155.0        39.0         Sports            30 - 60 Minute
# 210  Female       152.0        32.0         Sports             1 - 1.30 hour
# 211    Male       168.0        75.0         Cinema             1 - 1.30 hour
# 222    Male       160.0        50.0         Sports             1 - 1.30 hour
# ...

# %%
df.isna().sum() 
#checking for nan values
# Out:
# Gender                                                            0
# Height(CM)                                                        0
# Weight(KG)                                                        0
# Hobbies                                                           0
# Time on S-Media & V-Games                                         0
# 10th Grade score                                                  0
# 12th Grade score                                                  0
# Department                                                        0
# Certification (enrolled or completed)                             0
# College score                                                     0
# Preferred study period                                            0
# Daily studying time                                               0
# Do you like your degree?                                          0
# possibility of choosing  their career based on their degree :     0
# ...

# %% [markdown]
# ## Finding salary expectation mean per Department

# %%
bca_mean_sal = int(df[df['Department'] == 'BCA'].mean()[5])
bca_mean_sal

bcomism_mean_sal = int(df[df['Department'] == 'B.com ISM'].mean()[5])

commerce_mean_sal = int(df[df['Department'] == 'Commerce'].mean()[5])

bcomaf_mean_sal = int(df[df['Department'] == 'B.com Accounting and Finance '].mean()[5])

df[df['Department'] == 'B.com Accounting and Finance '].mean()
# Out:
# /var/folders/4y/3p248ngs2790s3zw19p7l4vc0000gn/T/ipykernel_40084/1822534863.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bca_mean_sal = int(df[df['Department'] == 'BCA'].mean()[5])
# /var/folders/4y/3p248ngs2790s3zw19p7l4vc0000gn/T/ipykernel_40084/1822534863.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bcomism_mean_sal = int(df[df['Department'] == 'B.com ISM'].mean()[5])
# ...

# %%
df.iloc[147]
#this actually helped to find out why i couldn't call on B.com Accounting and Finance
# Out:
# Gender                                                                                   Female
# Height(CM)                                                                                148.0
# Weight(KG)                                                                                 78.0
# Hobbies                                                                                  Cinema
# Time on S-Media & V-Games                                                        30 - 60 Minute
# 10th Grade score                                                                           71.2
# 12th Grade score                                                                           79.5
# Department                                                        B.com Accounting and Finance
# Certification (enrolled or completed)                                                       Yes
# College score                                                                              70.0
# ...

# %% [markdown]
# ## replacing salary expectation values with mean filtered by department

# %%
df.loc[(df['Department'] == 'BCA') & (df['Salary expectation'] == 0)].index
df.loc[[13, 17, 84], 'Salary expectation'] = bca_mean_sal
df.loc[[182, 196, 228, 230, 234], 'Salary expectation'] = bcomism_mean_sal
df.loc[[210, 211, 222], 'Salary expectation'] = commerce_mean_sal
df.loc[[51, 133, 147], 'Salary expectation'] = bcomaf_mean_sal


df.loc[[13,182,210,133]]
# Out:
#      Gender  Height(CM)  Weight(KG) Hobbies Time on S-Media & V-Games  \
# 13     Male       160.0        52.0  Cinema            30 - 60 Minute
# 182  Female       160.0        50.0  Sports            30 - 60 Minute
# 210  Female       152.0        32.0  Sports             1 - 1.30 hour
# 133    Male       174.0        65.0  Cinema             1 - 30 Minute
#
#      10th Grade score  12th Grade score                     Department  \
# 13               50.0              55.0                            BCA
# 182              60.0              70.0                      B.com ISM
# 210              80.0              60.0                       Commerce
# 133              90.0              85.0  B.com Accounting and Finance
#
#     Certification (enrolled or completed)  College score  \
# 13                                     No           50.0
# 182                                    No           65.0
# 210                                   Yes           70.0
# ...

# %% [markdown]
# ## changing the outlier in height

# %%
df.loc[96, 'Height(CM)'] = 134.0
df.loc[96]
# Out:
# Gender                                                                     Female
# Height(CM)                                                                  134.0
# Weight(KG)                                                                   42.0
# Hobbies                                                                    Cinema
# Time on S-Media & V-Games                                           1 - 1.30 hour
# 10th Grade score                                                             85.0
# 12th Grade score                                                             90.0
# Department                                                                    BCA
# Certification (enrolled or completed)                                         Yes
# College score                                                                85.0
# Preferred study period                                                    Anytime
# ...

# %%
df
# Out:
#      Gender  Height(CM)  Weight(KG)        Hobbies Time on S-Media & V-Games  \
# 0      Male       100.0        58.0    Video Games             1.30 - 2 hour
# 1    Female        90.0        40.0         Cinema             1 - 1.30 hour
# 2      Male       159.0        78.0         Cinema          More than 2 hour
# 3    Female       147.0        20.0  Reading books             1.30 - 2 hour
# 4      Male       170.0        54.0    Video Games             1.30 - 2 hour
# ..      ...         ...         ...            ...                       ...
# 230    Male       170.0        76.0    Video Games          More than 2 hour
# 231    Male       172.0        52.0         Cinema            30 - 60 Minute
# 232  Female       139.0        33.0         Cinema            30 - 60 Minute
# 233  Female       153.0        58.0         Cinema          More than 2 hour
# 234  Female       155.0        39.0         Sports            30 - 60 Minute
#
# ...

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)  10th Grade score  12th Grade score  \
# count  235.000000  235.000000        235.000000        235.000000
# mean   157.953191   60.803830         77.125532         68.780128
# std     19.100777   14.895844         12.233949         11.016533
# min     90.000000   20.000000         40.000000         45.000000
# 25%    152.000000   50.000000         70.000000         60.000000
# 50%    160.000000   60.000000         80.000000         69.000000
# 75%    170.000000   70.000000         86.250000         76.000000
# max    192.000000  106.000000         98.000000         94.000000
#
#        College score  Salary expectation
# count     235.000000          235.000000
# mean       70.660553        23177.731915
# std        15.727446        15912.651179
# min         1.000000        10000.000000
# 25%        60.000000        15000.000000
# 50%        70.000000        20000.000000
# 75%        80.000000        25000.000000
# ...

# %% [markdown]
# ## updating the 10th grade score

# %%
pour le score de 10th grade, il semblerait que ce soit plus une erreur d'entrée qu'autre chose en sachant qu'il faut plus 
de 33% pour réussir le concours/ l'examen

# %%
df[df['10th Grade score'] == 7.4]
df.loc[80, '10th Grade score'] = 74

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)  10th Grade score  12th Grade score  \
# count  235.000000  235.000000        235.000000        235.000000
# mean   157.953191   60.803830         77.125532         68.780128
# std     19.100777   14.895844         12.233949         11.016533
# min     90.000000   20.000000         40.000000         45.000000
# 25%    152.000000   50.000000         70.000000         60.000000
# 50%    160.000000   60.000000         80.000000         69.000000
# 75%    170.000000   70.000000         86.250000         76.000000
# max    192.000000  106.000000         98.000000         94.000000
#
#        College score  Salary expectation
# count     235.000000          235.000000
# mean       70.660553        23177.731915
# std        15.727446        15912.651179
# min         1.000000        10000.000000
# 25%        60.000000        15000.000000
# 50%        70.000000        20000.000000
# 75%        80.000000        25000.000000
# ...

# %% [markdown]
# ## now the college score issue

# %%
df[df['10th Grade score'] < 33]
# Out:
# Empty DataFrame
# Columns: [Gender, Height(CM), Weight(KG), Hobbies, Time on S-Media & V-Games, 10th Grade score, 12th Grade score, Department, Certification (enrolled or completed), College score, Preferred study period, Daily studying time, Do you like your degree?, possibility of choosing  their career based on their degree : , Salary expectation, Travelling Time , Working part-time, Financial Status, Stress Level ]
# Index: []

# %%
df_2 = df[['Height(CM)', 'Weight(KG)', '10th Grade score', '12th Grade score', 'College score', 'Salary expectation']]
df_2

for x in df_2.columns:
        plt.figure(figsize=(13,10))
        print(df.boxplot(column = x , vert= False))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.describe()
df.to_csv('SB_cleaned.csv', index=False)

# %% [markdown]
# # References for mean salaries, mean height and weight, CBSE marks

# %%
https://www.payscale.com/research/IN/Job=Computer_Scientist/Salary
https://www.payscale.com/research/IN/Job=Operations_Manager/Salary
https://www.payscale.com/research/IN/Job=Management_Information_System_Manager/Salary
https://www.payscale.com/research/IN/Job=Financial_Accountant/Salary
    
    
48 hour/Week maximum since factories act of 1948 
https://paycheck.in/labour-law-india/work-and-wages/work-hours-in-india

https://biz30.timedoctor.com/average-salary-in-india/ (average salaries) 
    
https://school.careers360.com/boards/cbse/cbse-passing-marks-for-class-10-and-12
grades for CBSE 10th & 12th mark

https://sain-et-naturel.ouest-france.fr/tableau-peser-age-taille.html
average height and weight for men and women
